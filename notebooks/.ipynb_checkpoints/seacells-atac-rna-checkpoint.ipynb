# %%
import warnings

warnings.filterwarnings( "ignore", module = "matplotlib\..*" )

import numpy as np
import pandas as pd
import scanpy as sc
sc.settings.verbosity = 0
import SEACells

import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns

# Peaks data
from scipy.io import mmread

# %matplotlib inline

sns.set_style('ticks')
matplotlib.rcParams['figure.figsize'] = [4, 4]
matplotlib.rcParams['figure.dpi'] = 100

sc.set_figure_params(figsize=(10,10),dpi=120)
# Out:
# findfont: Font family ['Raleway'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Lato'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# # Joint analysis of RNA & ATAC

# %%
filter_intersect = True
rna = sc.read_h5ad('../data/rna-multiome10x-mouse.h5ad')
atac = sc.read_h5ad('../data/atac-multiome10x-mouse.h5ad')

if filter_intersect:
    shared_cells = np.intersect1d(rna.obs.index,atac.obs.index)

    atac = atac[atac.obs.index.isin(shared_cells)]
    rna = rna[rna.obs.index.isin(shared_cells)]

    atac = atac[atac.obs.sort_index().index]
    rna = rna[rna.obs.sort_index().index]

    # Check that the dataframes are in the same order
    if all(atac.obs.index == rna.obs.index):
        print('Success')
# Out:
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# Success

# %% [markdown]
# ### Run SEACells on RNA

# %%
## Core parameters 
n_SEACells = int(len(rna)/75)
build_kernel_on = 'X_pca' # key in ad.obsm to use for computing metacells
                          # This would be replaced by 'X_svd' for ATAC data

## Additional parameters
n_waypoint_eigs = 10 # Number of eigenvalues to consider when initializing metacells

model = SEACells.core.SEACells(rna, 
                  build_kernel_on=build_kernel_on, 
                  n_SEACells=n_SEACells, 
                  n_waypoint_eigs=n_waypoint_eigs,
                  convergence_epsilon = 1e-5)

# %%
model.construct_kernel_matrix()
M = model.kernel_matrix
# Out:
# Computing kNN graph using scanpy NN ...
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/4349 [00:00<?, ?it/s]
# Making graph symmetric...
# Computing RBF kernel...
#   0%|          | 0/4349 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/4349 [00:00<?, ?it/s]
# Constructing CSR matrix...

# %%
sns.clustermap(M.toarray()[:500,:500])
# Out:
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
# Initialize archetypes
model.initialize_archetypes()
# Out:
# Building kernel on X_pca
# Computing diffusion components from X_pca for waypoint initialization ...
# Determing nearest neighbor graph...
# Done.
# Sampling waypoints ...
# Done.
# Selecting 51 cells from waypoint initialization.
# Initializing residual matrix using greedy column selection
# Initializing f and g...
#   0%|          | 0/16 [00:00<?, ?it/s]
# Selecting 6 cells from greedy initialization.

# %%
# Plot the initilization to ensure they are spread across phenotypic space
SEACells.plot.plot_initialization(rna, model)

# %%
model.fit(min_iter=10, max_iter=50)

# You can force the model to run additional iterations step-wise using the .step() function
print(f'Ran for {len(model.RSS_iters)} iterations')
for _ in range(5):
    model.step()
print(f'Ran for {len(model.RSS_iters)} iterations')
# Out:
# Randomly initialized A matrix.
# Setting convergence threshold at 0.00115
# Starting iteration 1.
# Completed iteration 1.
# Starting iteration 10.
# Completed iteration 10.
# Starting iteration 20.
# Completed iteration 20.
# Starting iteration 30.
# Completed iteration 30.
# Converged after 32 iterations.
# Ran for 33 iterations
# Ran for 38 iterations

# %%
# Check for convergence 
model.plot_convergence()

# %%
SEACell_rna = SEACells.core.summarize_by_SEACell(rna, SEACells_label='SEACell', summarize_layer='raw')
SEACell_rna
# Out:
#   0%|          | 0/57 [00:00<?, ?it/s]
# AnnData object with n_obs × n_vars = 57 × 32285
#     layers: 'raw'

# %%
SEACell_soft_ad = SEACells.core.summarize_by_soft_SEACell(rna, model.A_, celltype_label='leiden',summarize_layer='raw', minimum_weight=0.05)
SEACell_soft_ad
# Out:
#   0%|          | 0/57 [00:00<?, ?it/s]
# AnnData object with n_obs × n_vars = 57 × 32285
#     obs: 'Pseudo-sizes', 'celltype', 'celltype_purity'

# %%
SEACells.plot.plot_2D(rna, key='X_umap', colour_metacells=False)
# Out:
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/seaborn/relational.py:573: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   points = ax.scatter(x=x, y=y, **kws)
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/seaborn/relational.py:573: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   points = ax.scatter(x=x, y=y, **kws)

# %%
SEACells.plot.plot_2D(rna, key='X_umap', colour_metacells=True)
# Out:
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/seaborn/relational.py:573: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   points = ax.scatter(x=x, y=y, **kws)
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/seaborn/relational.py:573: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   points = ax.scatter(x=x, y=y, **kws)

# %%
SEACells.plot.plot_SEACell_sizes(rna, bins=6)

# rna[rna.obs['SEACell'].value_counts()[:10].index].obs['leiden'].value_counts()
# Out:
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/SEACells/plot.py:120: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(label_df.groupby('SEACell').count().iloc[:, 0], bins=bins)
#                     size
# SEACell
# AAGACCAAGTCAGTAC-1    61
# AAGCGAATCGACAAAG-1    84
# AATGTCATCGGTTTGG-1    75
# ACACTTAAGGTCATTA-1    56
# ACCAGCTCAGGCTTGT-1   136
# ACGAATCTCCCGCATT-1    73
# AGCAAGGGTGGCTTCC-1    69
# AGTGTGGCAGGATTAA-1   105
# ATAAGCCTCTCCTCTT-1   157
# ATACCTGCATGGCCCA-1    63
# CAAACACTCACTTCAT-1   120
# CAATCTAAGGTGTTAC-1   112
# CACAATATCTAATCTC-1    44
# CCAAGTTAGCAAGGTA-1    81
# CCAGGAACATGCTATG-1    30
# CCGTTGCGTATGGTGC-1    46
# CGAGTCGGTTAGACCA-1    39
# CGGTAACGTAGCAGCT-1    66
# CTAGTGAGTAGTTACG-1   140
# CTCAATAAGCTAAGTC-1    51
# CTCCGGACACTTACAG-1   174
# CTGCTCCCAGGGAGGA-1    87
# CTGGTTTGTCGCAAAC-1   139
# CTTTGAGCAGTCTAGC-1    87
# GAGTATCTCGGGCCAT-1    58
# GCCTCGACATTATCCC-1    68
# GCTAAGAAGGGTGGAT-1   133
# GCTATTGCAAACTCAT-1    47
# GGAAGCTAGTCAATCA-1    47
# GGATAACCAACTGGGA-1    46
# GGCGGTAAGTCATCCC-1    96
# GGCTGGTTCTTAGGAC-1    41
# GGTTAATGTATTGTGG-1    71
# GGTTATGGTGATCAGC-1    27
# GTAAGCGCACCTACTT-1    58
# GTAGGTGCAATAATGG-1   102
# GTAGTTATCACAGCGC-1    68
# GTTAGGCGTCGACTAA-1    44
# GTTCCCAGTCAGGCAT-1    42
# GTTCGCGCATCTTGAG-1    55
# TACCCGGCAATAACGA-1   145
# TACGCTTGTTTGCTGT-1   111
# TCAAGAACAAAGGCCA-1    68
# TCCATCATCATGGTTA-1    41
# TCCGGAATCACTTTAC-1    76
# TCGATTAAGCTGAGGG-1    71
# TCGGTAAGTCACCAAA-1    80
# TCGTTACGTTGCAATG-1    30
# TCTAACCGTTGTCATC-1   122
# TGCCATTGTACGTTTC-1    97
# TGGCCATCACAGAAAC-1    48
# TGGCGGTTCCAACTGG-1    50
# TGTAAAGCATCTAGCA-1    66
# TGTGCTGAGCTAATCA-1    38
# TTCAGGTAGTAACGAG-1    73
# TTGTGTGCAGCACGTT-1    69
# TTTGTGTTCAATGACC-1    66

# %%
compactness = SEACells.evaluate.compactness(rna, 'X_pca')

plt.figure(figsize=(4,4))
sns.boxplot(data=compactness, y='compactness')
plt.title('Compactness')
sns.despine()
plt.show()
plt.close()

compactness.head()
# Out:
# Determing nearest neighbor graph...
#                     compactness
# SEACell
# AAGACCAAGTCAGTAC-1     0.118507
# AAGCGAATCGACAAAG-1     0.002739
# AATGTCATCGGTTTGG-1     0.008366
# ACACTTAAGGTCATTA-1     0.063368
# ACCAGCTCAGGCTTGT-1     0.006292

# %%
rna.obs[rna.obs.index == compactness.sort_values(['compactness'],ascending=False).iloc[0].name]
# Out:
#                     n_counts leiden             SEACell
# index
# GCTATAGGTCCTTCAG-1    6327.0     15  GCTATAGGTCCTTCAG-1

# %%
separation = SEACells.evaluate.separation(rna, 'X_pca',nth_nbr=1)
plt.figure(figsize=(4,4))
sns.boxplot(data=separation, y='separation')
plt.title('Separation')
sns.despine()
plt.show()
plt.close()

separation.head()
# Out:
# Determing nearest neighbor graph...
#                     separation
# SEACell
# AAAGCAAGTTGCTGGG-1    0.452654
# AAGCAAGTCGCTAGTG-1    0.199205
# AAGCGAATCGACAAAG-1    0.056978
# ACGCAAGCACTTAGGC-1    0.114804
# ACGCAAGCAGTTTGGC-1    0.257302

# %% [markdown]
# ## Run SEACells on ATAC

# %%
## User defined parameters

## Core parameters 
n_SEACells = int(len(atac)/75)
build_kernel_on = 'X_svd' # key in ad.obsm to use for computing metacells
                          # This would be replaced by 'X_svd' for ATAC data

## Additional parameters
n_waypoint_eigs = 10 # Number of eigenvalues to consider when initializing metacells

model = SEACells.core.SEACells(atac, 
                  build_kernel_on=build_kernel_on, 
                  n_SEACells=n_SEACells, 
                  n_waypoint_eigs=n_waypoint_eigs,
                  convergence_epsilon = 1e-5)

# %%
model.construct_kernel_matrix()
M = model.kernel_matrix
# Out:
# Computing kNN graph using scanpy NN ...
# Computing radius for adaptive bandwidth kernel...
#   0%|          | 0/4349 [00:00<?, ?it/s]
# Making graph symmetric...
# Computing RBF kernel...
#   0%|          | 0/4349 [00:00<?, ?it/s]
# Building similarity LIL matrix...
#   0%|          | 0/4349 [00:00<?, ?it/s]
# Constructing CSR matrix...

# %%
sns.clustermap(M.toarray()[:500,:500])
# Out:
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/seaborn/matrix.py:560: UserWarning: Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#   warnings.warn(msg)

# %%
# Initialize archetypes
model.initialize_archetypes()
# Out:
# Building kernel on X_svd
# Computing diffusion components from X_svd for waypoint initialization ...
# Determing nearest neighbor graph...
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/palantir/utils.py:54: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   temp = sc.AnnData(data_df.values)
# Done.
# Sampling waypoints ...
# Done.
# Selecting 49 cells from waypoint initialization.
# Initializing residual matrix using greedy column selection
# Initializing f and g...
#   0%|          | 0/18 [00:00<?, ?it/s]
# Selecting 8 cells from greedy initialization.

# %%
# Plot the initilization to ensure they are spread across phenotypic space
SEACells.plot.plot_initialization(atac, model)

# %%
model.fit(min_iter=10, max_iter=50)
# Out:
# Randomly initialized A matrix.
# Setting convergence threshold at 0.00117
# Starting iteration 1.
# Completed iteration 1.
# Starting iteration 10.
# Completed iteration 10.
# Starting iteration 20.
# Completed iteration 20.
# Converged after 29 iterations.

# %%
# You can force the model to run additional iterations step-wise using the .step() function
print(f'Ran for {len(model.RSS_iters)} iterations')
for _ in range(5):
    model.step()
print(f'Ran for {len(model.RSS_iters)} iterations')

# Check for convergence 
model.plot_convergence()
# Out:
# Ran for 30 iterations
# Ran for 35 iterations

# %%
SEACell_atac = SEACells.core.summarize_by_SEACell(atac, SEACells_label='SEACell', summarize_layer='raw')
SEACell_atac
# Out:
#   0%|          | 0/57 [00:00<?, ?it/s]
# AnnData object with n_obs × n_vars = 57 × 122247
#     layers: 'raw'

# %%
SEACell_soft_ad = SEACells.core.summarize_by_soft_SEACell(atac, model.A_, celltype_label='leiden',summarize_layer='raw', minimum_weight=0.05)
SEACell_soft_ad
# Out:
#   0%|          | 0/57 [00:00<?, ?it/s]
# AnnData object with n_obs × n_vars = 57 × 122247
#     obs: 'Pseudo-sizes', 'celltype', 'celltype_purity'

# %%
SEACells.plot.plot_2D(atac, key='X_umap', colour_metacells=False)
# Out:
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/seaborn/relational.py:573: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   points = ax.scatter(x=x, y=y, **kws)
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/seaborn/relational.py:573: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   points = ax.scatter(x=x, y=y, **kws)

# %%
SEACells.plot.plot_2D(atac, key='X_umap', colour_metacells=True)
# Out:
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/seaborn/relational.py:573: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   points = ax.scatter(x=x, y=y, **kws)
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/seaborn/relational.py:573: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   points = ax.scatter(x=x, y=y, **kws)

# %%
SEACells.plot.plot_SEACell_sizes(atac, bins=6)
# Out:
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/SEACells/plot.py:120: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(label_df.groupby('SEACell').count().iloc[:, 0], bins=bins)
#                     size
# SEACell
# AACTCACAGTCATTGA-1    70
# AAGAACAGTCATAACG-1    35
# AAGTTTGTCAAATCGC-1   125
# AATCCGTAGAAGCTAG-1   117
# ACACCTTGTAAACAAG-1   139
# ACCAAGCGTGCCGCAA-1    77
# ACCCGGTAGCTTACTT-1    40
# ACCGGCTAGCGCTCAA-1    96
# ACCTTCCAGCTAATCA-1   122
# ACGAAGTCACCCACCT-1    84
# ACTCACCTCATTGCAA-1   137
# ACTCCTCAGTATTGCA-1   142
# AGCGCTCAGGCTACAT-1    31
# AGCTCATAGCTTTGTT-1    43
# AGTCGCATCAGTGAAG-1    48
# ATCGGCCAGGAGCACG-1    26
# ATTAGTCCAAACATAG-1    83
# ATTGCGCCATTAAGTC-1    79
# CAAACACTCACTTCAT-1    97
# CACGCTAAGATAAAGC-1    66
# CAGTATGGTAATGACT-1    54
# CCAACCCGTAGCTGGT-1   117
# CGAATCTAGCTTACTT-1    35
# CGGTTATAGAAGGTGC-1   106
# CGTAACCCAGTCTAGC-1    67
# CGTTATTTCTTTAGGA-1    58
# CTACCGGCATGTTGGC-1    92
# CTGACCAAGCTCCTTA-1    93
# CTTGAATCACAGGATG-1    77
# CTTGTCCAGGTGTTAC-1   130
# GATGCATTCTAATCAG-1    40
# GATTGCGTCTGTAATG-1    17
# GCCAACATCACACAGT-1    28
# GCGCTAGGTAACGTGC-1    35
# GCTAACAGTTTCGCGC-1    65
# GCTCCTTAGTTCCCGT-1   105
# GGAGCATAGTTATCCT-1   130
# GGCTATTAGCTATTAG-1    34
# GGCTCACAGGGATTAG-1    95
# GTAGGTGCAAGTTATC-1   156
# GTGTGCGGTTCGCGCT-1    38
# GTTCTCATCACCTGTC-1   121
# TAGAGCCGTCCTTTAA-1    78
# TAGGAACCACGTGCTG-1   156
# TCCTTGCAGGTCCACA-1    21
# TCGACAAGTTGAGGTC-1    25
# TCGATTAAGGCGGGTA-1    96
# TCTAACCGTTAAGCCA-1    30
# TCTAGCCTCTTTGTAC-1    62
# TGACTTAAGCATGCAT-1    88
# TGAGCTTAGAACCTGT-1    58
# TGCTTCCAGGCGCTAC-1    42
# TGGTCAAGTGATGAGG-1    42
# TTCAACCGTACAAAGA-1    77
# TTGAGGCGTTTGAGGC-1   126
# TTGTGAGGTTCGGGAT-1    27
# TTTGGTAAGCGATACT-1    71

# %% [markdown]
# ### Saving ATAC & RNA data SEACells

# %%
if all(rna_meta_ad.obs.sort_index().index == atac_meta_ad.obs.sort_index().index):
    rna.write('../data/seacells-rna-multiome10x-mouse.h5ad')
    atac.write('../data/seacells-atac-multiome10x-mouse.h5ad')

# %%
atac_meta_ad, rna_meta_ad = SEACells.genescores.prepare_multiome_anndata(atac, rna, SEACell_label='SEACell')
# Out:
# Generating Metacell matrices...
#  ATAC
# 100%|███████████████████████████████████████████████████████████████| 57/57 [00:02<00:00, 24.94it/s]
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/SEACells/genescores.py:59: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   atac_meta_ad = sc.AnnData(summ_matrix)
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/scanpy/preprocessing/_simple.py:524: ImplicitModificationWarning: Trying to modify attribute `.obs` of view, initializing view as actual.
#   adata.obs[key_n_counts] = counts_per_cell
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/scanpy/preprocessing/_normalization.py:155: UserWarning: Revieved a view of an AnnData. Making a copy.
#   view_to_actual(adata)
#  RNA
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# 100%|██████████████████████████████████████████████████████████████| 57/57 [00:00<00:00, 162.35it/s]
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/SEACells/genescores.py:80: FutureWarning: X.dtype being converted to np.float32 from float64. In the next version of anndata (0.9) conversion will not be automatic. Pass dtype explicitly to avoid this warning. Pass `AnnData(X, dtype=X.dtype, ...)` to get the future behavour.
#   rna_meta_ad = sc.AnnData(summ_matrix)
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
if all(rna_meta_ad.obs.sort_index().index == atac_meta_ad.obs.sort_index().index):
    atac_meta_ad.write('../data/seacell-meta-atac-multiome10x-mouse.h5ad')
    rna_meta_ad.write('../data/seacell-meta-rna-multiome10x-mouse.h5ad')
    print('Saved.')
# Out:
# Saved.

# %% [markdown]
# ### PEAK-GENE correlation analyses

# %%
rna = sc.read_h5ad('../data/seacells-rna-multiome10x-mouse.h5ad')
rna = rna[:,~rna.var.index.duplicated()]
atac = sc.read_h5ad('../data/seacells-atac-multiome10x-mouse.h5ad')
atac_meta_ad = sc.read_h5ad('../data/seacell-meta-atac-multiome10x-mouse.h5ad')
rna_meta_ad  = sc.read_h5ad('../data/seacell-meta-rna-multiome10x-mouse.h5ad')
rna_meta_ad = rna_meta_ad[:,~rna_meta_ad.var.index.duplicated()]
# Out:
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")
# /home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/anndata/_core/anndata.py:1830: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.
#   utils.warn_names_duplicates("var")

# %%
#Compute gene peak correlations for all highly variable genes

gene_set =rna[:,rna.var.highly_variable].var_names
gene_peak_cors = SEACells.genescores.get_gene_peak_correlations(atac_meta_ad, rna_meta_ad, 
                                           path_to_gtf='../gencode.vM10.annotation.gtf', 
                                           span=100000, 
                                           n_jobs=1,
                                           gene_set=gene_set)
# Out:
# Loading transcripts per gene...
# Preparing matrices for gene-peak associations
# Computing peak-gene correlations
#  20%|███████████▉                                                | 297/1500 [01:26<05:47,  3.46it/s]/home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1919: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
#  26%|███████████████▍                                            | 386/1500 [01:54<06:14,  2.98it/s]/home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1919: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
#  40%|████████████████████████▏                                   | 605/1500 [03:03<05:01,  2.97it/s]/home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1919: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
#  49%|█████████████████████████████▏                              | 731/1500 [03:41<05:05,  2.52it/s]/home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1919: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
#  87%|███████████████████████████████████████████████████▌       | 1311/1500 [06:29<01:07,  2.79it/s]/home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1919: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
#  97%|█████████████████████████████████████████████████████████▎ | 1456/1500 [07:12<00:09,  4.62it/s]/home/ak431480/.conda/envs/seacells/lib/python3.8/site-packages/scipy/stats/_distn_infrastructure.py:1919: RuntimeWarning: invalid value encountered in divide
#   x = np.asarray((x - loc)/scale, dtype=dtyp)
# 100%|███████████████████████████████████████████████████████████| 1500/1500 [07:20<00:00,  3.40it/s]

# %%
def p_adjust_bh(p):
    """Benjamini-Hochberg p-value correction for multiple hypothesis testing."""
    p = np.asfarray(p)
    by_descend = p.argsort()[::-1]
    by_orig = by_descend.argsort()
    steps = float(len(p)) / np.arange(len(p), 0, -1)
    q = np.minimum(1, np.minimum.accumulate(steps * p[by_descend]))
    return q[by_orig]

gene_peak_corr_df = pd.DataFrame()
for idx in gene_peak_cors.index:
    df = gene_peak_cors[idx]
    
    if isinstance(df, pd.DataFrame):
        df['Gene'] = idx
        gene_peak_corr_df = pd.concat([gene_peak_corr_df,df],axis=0)

gene_peak_corr_df = gene_peak_corr_df.replace(np.nan,1)
gene_peak_corr_df['adj_pval'] = p_adjust_bh(gene_peak_corr_df['pval'])

# %%
gene_peak_corr_df[gene_peak_corr_df['pval']<0.05].sort_values(['pval'])
# Out:
#                                cor          pval     Gene      adj_pval
# chr8:12183309-12183809    0.320441  3.925749e-13  Gm29175  1.145769e-08
# chr8:12301902-12302402    0.402305  6.700909e-09  Gm29175  9.778637e-05
# chr2:158610697-158611197  0.721043  1.525533e-06  Gm14204  1.484140e-02
# chr2:71516925-71517425    0.700488  2.441830e-06     Dlx1  1.781682e-02
# chr2:79456541-79457041    0.761068  4.622158e-06  Neurod1  2.269871e-02
# ...                            ...           ...      ...           ...
# chr7:27541874-27542374    0.369836  4.988799e-02      Prx  5.421604e-01
# chr1:74784392-74784892    0.290635  4.993101e-02     Wnt6  5.421604e-01
# chr3:34648765-34649265    0.524643  4.998132e-02     Sox2  5.421604e-01
# chr3:34593203-34593703    0.237278  4.998352e-02   Sox2ot  5.421604e-01
# chr7:140959441-140959941  0.297316  4.999997e-02   Ifitm3  5.421604e-01
#
# [2689 rows x 4 columns]

# %%
gene_peak_corr_df[gene_peak_corr_df['adj_pval']<0.05].sort_values(['adj_pval'])
# Out:
#                                cor          pval     Gene      adj_pval
# chr8:12183309-12183809    0.320441  3.925749e-13  Gm29175  1.145769e-08
# chr8:12301902-12302402    0.402305  6.700909e-09  Gm29175  9.778637e-05
# chr2:158610697-158611197  0.721043  1.525533e-06  Gm14204  1.484140e-02
# chr2:71516925-71517425    0.700488  2.441830e-06     Dlx1  1.781682e-02
# chr2:79456541-79457041    0.761068  4.622158e-06  Neurod1  2.269871e-02
# chr6:6870458-6870958      0.659498  4.666356e-06  Dlx6os1  2.269871e-02
# chr14:65416775-65417275   0.538075  8.241398e-06     Pnoc  3.436192e-02
# chr12:32208436-32208936   0.454646  1.205134e-05   Pik3cg  4.396631e-02
